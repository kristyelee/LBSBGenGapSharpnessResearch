# %%
import numpy as np
data_for_plotting = np.load('intermediate-values3.npy')
batch_range = [25, 50, 80, 125]
print(data_for_plotting)
data_for_plotting = np.load('intermediate-values.npy')
print(data_for_plotting[:12])
batch_range = [25, 50, 80, 125, 250, 500, 625, 1000, 1250, 2000, 2500, 3125]
data_for_plotting = data_for_plotting[:12]
data_for_plotting.shape
# 125, 80, 50, 25
# Out:
# [[6.96800000e+01 0.00000000e+00 0.00000000e+00]
#  [7.29500000e+01 7.91228922e-06 0.00000000e+00]
#  [7.28900000e+01 4.65733365e-06 4.65733365e-06]
#  [7.32700000e+01 4.72872238e+01 0.00000000e+00]]
# [[7.66400000e+01 0.00000000e+00 0.00000000e+00]
#  [8.29800000e+01 0.00000000e+00 0.00000000e+00]
#  [8.32900000e+01 5.94288349e-06 0.00000000e+00]
#  [8.30600000e+01 0.00000000e+00 0.00000000e+00]
#  [8.28600000e+01 8.23157196e+01 6.08683513e-06]
#  [8.27200000e+01 2.63759460e+02 1.29905273e+02]
#  [8.20600000e+01 2.34844452e+02 8.25539551e+01]
#  [8.10500000e+01 2.29022598e+02 1.37386963e+02]
#  [8.00500000e+01 4.16336639e+02 1.21364250e+02]
#  [7.80200000e+01 5.36541862e+01 4.34153595e+01]
#  [7.72700000e+01 1.01700378e+02 4.96964539e+02]
#  [7.59100000e+01 3.65874420e+02 4.32308044e+02]]
# (12, 3)

# %%
np.load('intermediate-values2.npy')
# Out:
# array([[77.32,  0.  ,  0.  ],
#        [78.32,  0.  ,  0.  ],
#        [78.98,  0.  ,  0.  ],
#        [79.84,  0.  ,  0.  ],
#        [79.46,  0.  ,  0.  ],
#        [77.14,  0.  ,  0.  ],
#        [76.8 ,  0.  ,  0.  ],
#        [73.4 ,  0.  ,  0.  ],
#        [70.88,  0.  ,  0.  ],
#        [59.48,  0.  ,  0.  ],
#        [54.28,  0.  ,  0.  ],
#        [40.22,  0.  ,  0.  ],
#        [29.75,  0.  ,  0.  ]])

# %%
import matplotlib.pyplot as plt
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(batch_range, data_for_plotting[:, 0], 'b-')

ax2.plot(batch_range, data_for_plotting[:, 1], 'r-')
ax2.plot(batch_range, data_for_plotting[:, 2], 'r--')

ax1.set_xlabel('Batch Size')
ax1.set_ylabel('Testing Accuracy', color='b')
ax2.set_ylabel('Sharpness', color='r')
ax2.legend(('1e-3', '5e-4'), loc=0)

ax1.grid(b=True, which='both')
print('Saved figure; Task complete')
# Out:
# Saved figure; Task complete

# %%
data_for_plotting = np.load('intermediate-values3.npy')
batch_range = [25, 50, 80, 125]
print(data_for_plotting)
import matplotlib.pyplot as plt
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(batch_range, data_for_plotting[:, 0], 'b-')

ax2.plot(batch_range, data_for_plotting[:, 1], 'r-')
ax2.plot(batch_range, data_for_plotting[:, 2], 'r--')

ax1.set_xlabel('Batch Size')
ax1.set_ylabel('Testing Accuracy', color='b')
ax2.set_ylabel('Sharpness', color='r')
ax2.legend(('1e-3', '5e-4'), loc=0)

ax1.grid(b=True, which='both')
print('Saved figure; Task complete')
# Out:
# [[6.96800000e+01 0.00000000e+00 0.00000000e+00]
#  [7.29500000e+01 7.91228922e-06 0.00000000e+00]
#  [7.28900000e+01 4.65733365e-06 4.65733365e-06]
#  [7.32700000e+01 4.72872238e+01 0.00000000e+00]]
# Saved figure; Task complete

# %%
data_for_plotting = np.load('30EpochC3Experiment-intermediate-values.npy')[1:]
data_for_plotting
# Out:
# array([[8.20900000e+01, 2.30871137e-05, 1.09373486e-05],
#        [8.23400000e+01, 5.40150359e-06, 0.00000000e+00],
#        [8.26800000e+01, 0.00000000e+00, 0.00000000e+00],
#        [8.32500000e+01, 0.00000000e+00, 5.69462736e-06],
#        [8.27200000e+01, 6.06593267e-06, 0.00000000e+00],
#        [8.34300000e+01, 5.64910624e-06, 1.69473187e-05],
#        [8.27900000e+01, 1.43276550e+02, 0.00000000e+00],
#        [8.26200000e+01, 2.53562927e+02, 6.75661469e+01],
#        [8.16800000e+01, 3.82013458e+02, 1.98113708e+02],
#        [8.11300000e+01, 1.39567154e+02, 7.17146835e+01],
#        [8.05400000e+01, 5.26399902e+02, 1.92293732e+02],
#        [7.98200000e+01, 2.44532349e+02, 9.80392075e+01],
#        [7.86200000e+01, 2.64547607e+02, 5.42139465e+02],
#        [7.78500000e+01, 7.06375671e+02, 6.12322388e+01],
#        [7.72300000e+01, 0.00000000e+00, 0.00000000e+00],
#        [7.67700000e+01, 0.00000000e+00, 0.00000000e+00],
#        [7.59500000e+01, 0.00000000e+00, 0.00000000e+00]])

# %%
batch_range = [40, 50, 64, 80, 128, 256, 512, 625, 1024, 1250, 1750, 2048, 2500, 3125, 4096, 4500, 5000]
import matplotlib.pyplot as plt
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(batch_range, data_for_plotting[:, 0], 'b-')

batch_range = [40, 50, 64, 80, 128, 256, 512, 625, 1024, 1250, 1750, 2048, 2500, 3125]
data_for_plotting = data_for_plotting[:14]
data_for_plotting
ax2.plot(batch_range, data_for_plotting[:, 1], 'r-')
ax2.plot(batch_range, data_for_plotting[:, 2], 'r--')

ax1.set_xlabel('Batch Size')
ax1.set_ylabel('Testing Accuracy', color='b')
ax2.set_ylabel('Sharpness', color='r')
ax2.legend(('1e-3', '5e-4'), loc=0)

ax1.grid(b=True, which='both')
print('Saved figure; Task complete')
# Out:
# Saved figure; Task complete

# %%
data_for_plotting = np.load('ShallowNetCIFAR10-intermediate-values.npy')
data_for_plotting
# Out:
# array([[7.77100000e+01, 1.03343290e-03, 0.00000000e+00],
#        [7.72100000e+01, 7.97276152e-04, 0.00000000e+00],
#        [7.67400000e+01, 0.00000000e+00, 4.65048826e-04],
#        [7.63900000e+01, 3.36861558e-05, 8.00046197e-04],
#        [7.69400000e+01, 3.41764884e-04, 3.41764884e-04],
#        [7.61400000e+01, 2.27116998e-05, 3.74743046e-04],
#        [7.59900000e+01, 6.86996864e-05, 2.91973673e-04],
#        [7.56700000e+01, 3.11052170e+01, 1.46786006e-05],
#        [7.50400000e+01, 5.49851036e+00, 0.00000000e+00],
#        [7.46800000e+01, 9.52485275e+01, 4.07238222e-05],
#        [7.46500000e+01, 1.97375900e+02, 0.00000000e+00],
#        [7.40700000e+01, 1.47989044e+02, 4.04805323e-04],
#        [7.28400000e+01, 1.00605554e+03, 9.93238754e+01],
#        [7.29100000e+01, 1.71752899e+02, 2.06753418e+02],
#        [7.18600000e+01, 8.21722290e+02, 5.11357651e+01],
#        [7.18600000e+01, 5.10672264e+01, 2.89040161e+02],
#        [7.19900000e+01, 2.96139160e+02, 2.45507355e+02],
#        [7.12100000e+01, 2.21012695e+03, 2.69940147e+01]])

# %%
batch_range=[25, 40, 50, 64, 80, 128, 256, 512, 625, 1024, 1250, 1750, 2048, 2500, 3125, 4096, 4500, 5000]
import matplotlib.pyplot as plt
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(batch_range, data_for_plotting[:, 0], 'b-')

batch_range = [25, 40, 50, 64, 80, 128, 256, 512, 625, 1024, 1250, 1750, 2048, 2500, 3125, 4096, 4500, 5000]
data_for_plotting = data_for_plotting
ax2.plot(batch_range, data_for_plotting[:, 1], 'r-')
ax2.plot(batch_range, data_for_plotting[:, 2], 'r--')

ax1.set_xlabel('Batch Size')
ax1.set_ylabel('Testing Accuracy', color='b')
ax2.set_ylabel('Sharpness', color='r')
ax2.legend(('1e-3', '5e-4'), loc=9)

ax1.grid(b=True, which='both')
print('Saved figure; Task complete')
# Out:
# Saved figure; Task complete
